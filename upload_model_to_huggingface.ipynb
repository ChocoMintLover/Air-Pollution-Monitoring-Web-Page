# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

# %%
model = tf.keras.models.load_model('./models/mj_fine_tuned_gru_model_capable.h5')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14324\796407198.py in <module>
# ----> 1 model = tf.keras.models.load_model('./models/mj_fine_tuned_gru_model_capable.h5')
#
# c:\Users\minja\anaconda3\envs\tf210\lib\site-packages\tensorflow\python\keras\saving\save.py in load_model(filepath, custom_objects, compile)
#     182     if (h5py is not None and (
#     183         isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 184       return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     185
#     186     if sys.version_info >= (3, 4) and isinstance(filepath, pathlib.Path):
#
# c:\Users\minja\anaconda3\envs\tf210\lib\site-packages\tensorflow\python\keras\saving\hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     176     model_config = json.loads(model_config.decode('utf-8'))
# ...

# %%
busan_df = pd.read_csv('./pollution_data/baseline_data/Busan_pollution_data_3_years.csv')
features = ['aqi', 'co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10', 'nh3']
busan_df = busan_df[features]

# %%
data_array = busan_df.to_numpy()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
data_scaled = scaler.fit_transform(data_array)

# %%
plt.plot(model.predict(data_scaled[:30].reshape(-1, 30, 9))[-1])
# Out:
# 1/1 [==============================] - 1s 743ms/step
# ...

# %%
import tensorflowjs
# Out:
# WARNING:root:Failure to load the inference.so custom c++ tensorflow ops. This error is likely caused the version of TensorFlow and TensorFlow Decision Forests are not compatible. Full error:c:\Users\minja\anaconda3\envs\tfjs_convert\lib\site-packages\tensorflow_decision_forests\tensorflow\ops\inference\inference.so not found
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import tensorflowjs
#
# File c:\Users\minja\anaconda3\envs\tfjs_convert\lib\site-packages\tensorflowjs\__init__.py:21
#      18 from __future__ import print_function
#      20 # pylint: disable=unused-imports
# ---> 21 from tensorflowjs import converters
#      22 from tensorflowjs import quantization
#      23 from tensorflowjs import version
#
# File c:\Users\minja\anaconda3\envs\tfjs_convert\lib\site-packages\tensorflowjs\converters\__init__.py:21
# ...
